# %%
import pandas as pd

# %%
team_mapping = {'ARS':'Arsenal', 
                'AVL':'Aston Villa', 
                'BHA':'Brighton', 
                'BOU':'Bournemouth', 'BUR':'Burnley', 'CHE':'Chelsea', 'CRY':'Crystal Palace', 'EVE':'Everton', 'LEI':'Leicester', 'LIV':'Liverpool', 'MCI':'Manchester City', 'MUN':'Manchester United', 'NEW':'Newcastle United', 'NOR':'Norwich City', 'SHU':'Sheffield United', 'SOU':'Southampton', 'TOT':'Tottenham', 'WAT':'Watford', 'WHU':'West Ham', 'WOL':'Wolverhampton Wanderers'}

# %%
list_of_teams = []
for team_name in team_mapping.values():
    team = pd.read_csv('teams\merged_' + team_name + '.csv')
    list_of_teams.append(team)
    print('teams\merged_' + team_name + '.csv')
# Out:
# teams\merged_Arsenal.csv
# teams\merged_Aston Villa.csv
# teams\merged_Brighton.csv
# teams\merged_Bournemouth.csv
# teams\merged_Burnley.csv
# teams\merged_Chelsea.csv
# teams\merged_Crystal Palace.csv
# teams\merged_Everton.csv
# teams\merged_Leicester.csv
# teams\merged_Liverpool.csv
# teams\merged_Manchester City.csv
# teams\merged_Manchester United.csv
# teams\merged_Newcastle United.csv
# teams\merged_Norwich City.csv
# teams\merged_Sheffield United.csv
# teams\merged_Southampton.csv
# teams\merged_Tottenham.csv
# teams\merged_Watford.csv
# teams\merged_West Ham.csv
# teams\merged_Wolverhampton Wanderers.csv

# %%
list_of_teams
# Out:
# [    Unnamed: 0          Unnamed: 0_x     Player Name Team Position  Assists  \
#  0            0      AubameyangARSFWD      Aubameyang  ARS      FWD      7.0
#  1            1        BellerínARSDEF        Bellerín  ARS      DEF      5.0
#  2            2          ElnenyARSMID          Elneny  ARS      MID      0.0
#  3            3       GuendouziARSMID       Guendouzi  ARS      MID      0.0
#  4            4         HoldingARSDEF         Holding  ARS      DEF      0.0
#  5            5           IwobiARSMID           Iwobi  ARS      MID      8.0
#  6            6       JenkinsonARSDEF       Jenkinson  ARS      DEF      0.0
#  7            7       KolasinacARSDEF       Kolasinac  ARS      DEF      7.0
#  8            8       KoscielnyARSDEF       Koscielny  ARS      DEF      0.0
#  9            9       LacazetteARSFWD       Lacazette  ARS      FWD     12.0
#  10          10            LenoARSGKP            Leno  ARS      GKP      0.0
# ...
